# %%
student_name = "Andrea"
team = "Caro, Clemente and Jorge"

print("Hello, World!")
print("Welcome,", student_name)
print("Course: Algorithms and Data Analysis")
#For this print, I placed the names of my teammates in a single variable.
print("Today we are practicing Git collaboration with my team:", team)
# Out:
# Hello, World!
# Welcome, Andrea
# Course: Algorithms and Data Analysis
# Today we are practicing Git collaboration with my team: Caro, Clemente and Jorge
